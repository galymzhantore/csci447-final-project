# %% [markdown]
# # Edge Fluency Demo
# This notebook showcases the end-to-end workflow on a handful of clips.

# %%
import json, yaml, pandas as pd
from pathlib import Path
CONFIG = Path('config/default.yaml')
cfg = yaml.safe_load(CONFIG.read_text())
cfg['data']['output_dir'] = 'experiments'
print(cfg['data'])

# %%
# !make download LANGS="en"

# %%
# !make features

# %%
# !make train_student

# %%
from pathlib import Path
import json
metrics = json.loads(Path('experiments/metrics/evaluation.json').read_text())
metrics['splits']['test']
