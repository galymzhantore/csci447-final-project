# %% [markdown]
# # Demo Android Pipeline
#
# This notebook documents the end-to-end steps for exporting the quantized pronunciation model and syncing it with the Android Studio project.

# %% [markdown]
# ## 1. Train + Export
#
# Run the standard workflow (download, features, train, quantize) before exporting the final TensorFlow Lite artifacts.

# %%
# !make export_tflite
# !make convert_android

# %% [markdown]
# ## 2. Build & Profile
#
# Open `android_app/` in Android Studio Iguana, run on a physical tablet, and capture profiler traces (latency, memory, energy). The resulting metrics are copied back into `results/profile_summary.json` via `make android_profile`.
